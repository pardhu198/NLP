# %%
import nltk
import spacy

# %%
text = """The old lighthouse stood stoically against the relentless assault of the sea, its beacon a solitary eye piercing through the impenetrable fog. Generations of keepers had etched their stories into its weathered stones, whispers of lonely nights and heroic rescues echoing in the salt-laced air. A flock of gulls wheeled overhead, their cries a mournful counterpoint to the crashing waves, as if lamenting the passage of time and the inevitable decay that awaited even the most steadfast of structures. Yet, for now, it remained a steadfast sentinel, a silent guardian of the treacherous coast."""

words = text.split()
word_count = len(words)

print(f"The paragraph contains {word_count} words.")
# Out:
# The paragraph contains 94 words.

# %%
lowercase_text = text.lower()
print(lowercase_text)
# Out:
# the old lighthouse stood stoically against the relentless assault of the sea, its beacon a solitary eye piercing through the impenetrable fog. generations of keepers had etched their stories into its weathered stones, whispers of lonely nights and heroic rescues echoing in the salt-laced air. a flock of gulls wheeled overhead, their cries a mournful counterpoint to the crashing waves, as if lamenting the passage of time and the inevitable decay that awaited even the most steadfast of structures. yet, for now, it remained a steadfast sentinel, a silent guardian of the treacherous coast.
